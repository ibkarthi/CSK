# %%
import folium
import pandas as pd
import numpy as np

# %%
# Import folium MarkerCluster plugin
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
csk = pd.read_csv('csk(sql).csv')
csk
# Out:
#      Match        Date     Ground                        Team1  \
# 0        2  2008-04-19     Mohali                 Punjab Kings
# 1        8  2008-04-23    Chennai          Chennai Super Kings
# 2       11  2008-04-26    Chennai          Chennai Super Kings
# 3       15  2008-04-28  Bengaluru  Royal Challengers Bangalore
# 4       20  2008-05-02    Chennai          Chennai Super Kings
# ..     ...         ...        ...                          ...
# 189    859  2021-10-02  Abu Dhabi          Chennai Super Kings
# 190    862  2021-10-04      Dubai          Chennai Super Kings
# 191    865  2021-10-07      Dubai          Chennai Super Kings
# 192    869  2021-10-10      Dubai          Chennai Super Kings
# 193    872  2021-10-15      Dubai          Chennai Super Kings
#
#                      Team2               Winner       Win by  \
# 0      Chennai Super Kings  Chennai Super Kings  1st Batting
# 1           Mumbai Indians  Chennai Super Kings  1st Batting
# ...

# %%
csk['Ground'].unique()
# Out:
# array(['Mohali', 'Chennai', 'Bengaluru', 'Jaipur', 'Delhi', 'Mumbai',
#        'Kolkata', 'Hyderabad', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'East London', 'Johannesburg', 'Centurion', 'Kimberley',
#        'Ahmedabad', 'Nagpur', 'Dharamsala', 'Kochi', 'Visakhapatnam',
#        'Pune', 'Abu Dhabi', 'Dubai', 'Sharjah', 'Ranchi', 'Cuttack',
#        'Raipur'], dtype=object)

# %%
# Ground cities and their corresponding co-ordinates
Mohali = [30.67995, 76.72211]
Chennai = [13.08784, 80.27847] 
Bengaluru = [12.97194, 77.59369]
Jaipur = [26.91962, 75.78781]
Delhi = [28.65195, 77.23149]
Mumbai = [19.07283, 72.88261]
Kolkata = [22.56263, 88.36304]
Hyderabad = [17.38405, 78.45636]
Ahmedabad = [23.02579, 72.58727]
Nagpur = [21.14631, 79.08491]
Dharamsala = [32.22006, 76.32013]
Kochi = [9.93988, 76.26022]
Visakhapatnam = [17.68009, 83.20161]
Pune = [18.51957, 73.85535]
Ranchi = [23.34777, 85.33856]
Cuttack = [20.46497, 85.87927]
Raipur = [30.31097, 78.08979]
CapeTown = [-33.918861, 18.423300]
PortElizabeth = [-33.958252, 25.619022]
Durban = [-29.861825, 31.009909]
EastLondon = [-33.029158, 27.854587]
Johannesburg = [-26.204103, 28.047305]
Centurion = [-25.864029, 28.088858]
Kimberley = [-28.741943, 24.771944]
AbuDhabi = [24.466667, 54.366669]
Dubai = [25.276987, 55.296249]
Sharjah = [25.346255, 55.420932]
#nasa_coordinate = [29.559684888503615, -95.0830971930759]

# %%
site_map = folium.Map(location=Dubai, zoom_start=10)
circle = folium.Circle(Dubai, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('Dubai'))
marker = folium.map.Marker(
    Dubai,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'Dubai',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
def site(coordinate, LaunchSite):
    circle = folium.Circle(coordinate, radius=1000, color='#000000', fill=True).add_child(folium.Popup(LaunchSite))
    marker = folium.map.Marker(
        coordinate,
        # Create an icon as a text label
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            html='<div style="font-size: 30; color:#d35400;"><b>%s</b></div>' %LaunchSite,
            )
        )
    site_map.add_child(circle)
    site_map.add_child(marker)

# %%
site(Mohali, 'Mohali')
site(Chennai, 'Chennai')
site(Bengaluru, 'Bengaluru')
site(Jaipur, 'Jaipur')
site(Delhi, 'Delhi')
site(Mumbai, 'Mumbai')
site(Kolkata, 'Kolkata')
site(Hyderabad, 'Hyderabad')
site(Ahmedabad, 'Ahmedabad')
site(Nagpur, 'Nagpur')
site(Dharamsala, 'Dharamsala')
site(Kochi, 'Kochi')
site(Visakhapatnam, 'Visakhapatnam')
site(Pune, 'Pune')
site(Ranchi, 'Ranchi')
site(Cuttack, 'Cuttack')
site(Raipur, 'Raipur')
site(CapeTown, 'CapeTown')
site(PortElizabeth, 'PortElizabeth')
site(Durban, 'Durban')
site(EastLondon, 'EastLondon')
site(Johannesburg, 'Johannesburg')
site(Centurion, 'Centurion')
site(Kimberley, 'Kimberley')
site(AbuDhabi, 'AbuDhabi')
site(Dubai, 'Dubai')
site(Sharjah, 'Sharjah')

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
csk['Lat'] = csk['Ground']
csk['Long'] = csk['Ground']

# %%
csk['Lat'] = csk['Lat'].map({'Mohali': Mohali[0], 'Chennai': Chennai[0], 'Bengaluru': Bengaluru[0], 'Jaipur': Jaipur[0], 'Delhi': Delhi[0], 'Mumbai': Mumbai[0],
       'Kolkata': Kolkata[0], 'Hyderabad': Hyderabad[0], 'Cape Town': CapeTown[0], 'Port Elizabeth': PortElizabeth[0], 'Durban': Durban[0],
       'East London': EastLondon[0], 'Johannesburg': Johannesburg[0], 'Centurion': Centurion[0], 'Kimberley': Kimberley[0],
       'Ahmedabad': Ahmedabad[0], 'Nagpur': Nagpur[0], 'Dharamsala': Dharamsala[0], 'Kochi': Kochi[0], 'Visakhapatnam': Visakhapatnam[0],
       'Pune': Pune[0], 'Abu Dhabi': AbuDhabi[0], 'Dubai':Dubai[0], 'Sharjah':Sharjah[0], 'Ranchi': Ranchi[0], 'Cuttack': Cuttack[0],
       'Raipur': Raipur[0]})

# %%
csk['Long'] = csk['Long'].map({'Mohali': Mohali[1], 'Chennai': Chennai[1], 'Bengaluru': Bengaluru[1], 'Jaipur': Jaipur[1], 'Delhi': Delhi[1], 'Mumbai': Mumbai[1],
       'Kolkata': Kolkata[1], 'Hyderabad': Hyderabad[1], 'Cape Town': CapeTown[1], 'Port Elizabeth': PortElizabeth[1], 'Durban': Durban[1],
       'East London': EastLondon[1], 'Johannesburg': Johannesburg[1], 'Centurion': Centurion[1], 'Kimberley': Kimberley[1],
       'Ahmedabad': Ahmedabad[1], 'Nagpur': Nagpur[1], 'Dharamsala': Dharamsala[1], 'Kochi': Kochi[1], 'Visakhapatnam': Visakhapatnam[1],
       'Pune': Pune[1], 'Abu Dhabi': AbuDhabi[1], 'Dubai':Dubai[1], 'Sharjah':Sharjah[1], 'Ranchi': Ranchi[1], 'Cuttack': Cuttack[1],
       'Raipur': Raipur[1]})

# %%
csk.head()
# Out:
#    Match        Date     Ground                        Team1  \
# 0      2  2008-04-19     Mohali                 Punjab Kings
# 1      8  2008-04-23    Chennai          Chennai Super Kings
# 2     11  2008-04-26    Chennai          Chennai Super Kings
# 3     15  2008-04-28  Bengaluru  Royal Challengers Bangalore
# 4     20  2008-05-02    Chennai          Chennai Super Kings
#
#                    Team2               Winner       Win by  \
# 0    Chennai Super Kings  Chennai Super Kings  1st Batting
# 1         Mumbai Indians  Chennai Super Kings  1st Batting
# 2  Kolkata Knight Riders  Chennai Super Kings      Chasing
# 3    Chennai Super Kings  Chennai Super Kings  1st Batting
# 4         Delhi Capitals       Delhi Capitals      Chasing
#
#                       Opponent        Day  csk       Lat      Long
# 0                 Punjab Kings   Saturday    1  30.67995  76.72211
# 1               Mumbai Indians  Wednesday    1  13.08784  80.27847
# ...

# %%
csk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Match     194 non-null    int64
#  1   Date      194 non-null    object
#  2   Ground    194 non-null    object
#  3   Team1     194 non-null    object
#  4   Team2     194 non-null    object
#  5   Winner    194 non-null    object
#  6   Win by    194 non-null    object
#  7   Opponent  194 non-null    object
#  8   Day       194 non-null    object
#  9   csk       194 non-null    int64
#  10  Lat       194 non-null    float64
#  11  Long      194 non-null    float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 18.3+ KB

# %%
location = csk[['Ground', 'Lat', 'Long', 'csk']]

# %%
location.head()
# Out:
#       Ground       Lat      Long  csk
# 0     Mohali  30.67995  76.72211    1
# 1    Chennai  13.08784  80.27847    1
# 2    Chennai  13.08784  80.27847    1
# 3  Bengaluru  12.97194  77.59369    1
# 4    Chennai  13.08784  80.27847    0

# %%
marker_cluster = MarkerCluster()

# %%
def assign_marker_color(outcome):
    if outcome == 1:
        return 'green'
    else:
        return 'red'
    
location['marker_color'] = location['csk'].apply(assign_marker_color)
# Out:
# c:\users\ibd\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
location.tail()
# Out:
#         Ground        Lat       Long  csk marker_color
# 189  Abu Dhabi  24.466667  54.366669    0          red
# 190      Dubai  25.276987  55.296249    0          red
# 191      Dubai  25.276987  55.296249    0          red
# 192      Dubai  25.276987  55.296249    1        green
# 193      Dubai  25.276987  55.296249    1        green

# %%
site_map.add_child(marker_cluster)

# for each row in spacex_df data frame
# create a Marker object with its coordinate
# and customize the Marker's icon property to indicate if this launch was successed or failed, 
# e.g., icon=folium.Icon(color='white', icon_color=row['marker_color']
for index, record in location.iterrows():
    # TODO: Create and add a Marker cluster to the site map
    marker = folium.map.Marker([record['Lat'], record['Long']],
        # Create an icon as a text label
            icon=folium.Icon(color='white', icon_color=record['marker_color'],
            ))#.add_to(marker_cluster)
    marker_cluster.add_child(marker)

site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# Add Mouse Position to get the coordinate (Lat, Long) for a mouse over on the map
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#site_map.save('IPL_Pitch_Loc.html')

# %%
import io
from PIL import Image

# %%
#img_data = site_map._to_png(5)
#img = Image.open(io.BytesIO(img_data))
#img.save('IPL_Pitch_Loc1.png')

# %%
pitchdf = pd.read_csv('pitchwin.csv')
pitchdf
# Out:
#             Ground  Cskplayed  Cskwon    Win%   Lose%
# 0          Chennai         56      40   71.43   28.57
# 1           Mumbai         25      15   60.00   40.00
# 2            Dubai         14       9   64.29   35.71
# 3          Kolkata         11       5   45.45   54.55
# 4            Delhi         10       7   70.00   30.00
# 5        Bengaluru          9       5   55.56   44.44
# 6             Pune          8       6   75.00   25.00
# 7        Abu Dhabi          8       4   50.00   50.00
# 8          Sharjah          6       3   50.00   50.00
# 9           Mohali          6       3   50.00   50.00
# 10          Jaipur          6       3   50.00   50.00
# 11       Hyderabad          6       3   50.00   50.00
# 12          Ranchi          5       3   60.00   40.00
# 13          Durban          4       1   25.00   75.00
# 14   Visakhapatnam          2       2  100.00    0.00
# 15  Port Elizabeth          2       2  100.00    0.00
# ...

# %%
pitchdf['Lat'] = pitchdf['Ground']
pitchdf['Long'] = pitchdf['Ground']

# %%
pitchdf['Lat'] = pitchdf['Lat'].map({'Mohali': Mohali[0], 'Chennai': Chennai[0], 'Bengaluru': Bengaluru[0], 'Jaipur': Jaipur[0], 'Delhi': Delhi[0], 'Mumbai': Mumbai[0],
       'Kolkata': Kolkata[0], 'Hyderabad': Hyderabad[0], 'Cape Town': CapeTown[0], 'Port Elizabeth': PortElizabeth[0], 'Durban': Durban[0],
       'East London': EastLondon[0], 'Johannesburg': Johannesburg[0], 'Centurion': Centurion[0], 'Kimberley': Kimberley[0],
       'Ahmedabad': Ahmedabad[0], 'Nagpur': Nagpur[0], 'Dharamsala': Dharamsala[0], 'Kochi': Kochi[0], 'Visakhapatnam': Visakhapatnam[0],
       'Pune': Pune[0], 'Abu Dhabi': AbuDhabi[0], 'Dubai':Dubai[0], 'Sharjah':Sharjah[0], 'Ranchi': Ranchi[0], 'Cuttack': Cuttack[0],
       'Raipur': Raipur[0]})

# %%
pitchdf['Long'] = pitchdf['Long'].map({'Mohali': Mohali[1], 'Chennai': Chennai[1], 'Bengaluru': Bengaluru[1], 'Jaipur': Jaipur[1], 'Delhi': Delhi[1], 'Mumbai': Mumbai[1],
       'Kolkata': Kolkata[1], 'Hyderabad': Hyderabad[1], 'Cape Town': CapeTown[1], 'Port Elizabeth': PortElizabeth[1], 'Durban': Durban[1],
       'East London': EastLondon[1], 'Johannesburg': Johannesburg[1], 'Centurion': Centurion[1], 'Kimberley': Kimberley[1],
       'Ahmedabad': Ahmedabad[1], 'Nagpur': Nagpur[1], 'Dharamsala': Dharamsala[1], 'Kochi': Kochi[1], 'Visakhapatnam': Visakhapatnam[1],
       'Pune': Pune[1], 'Abu Dhabi': AbuDhabi[1], 'Dubai':Dubai[1], 'Sharjah':Sharjah[1], 'Ranchi': Ranchi[1], 'Cuttack': Cuttack[1],
       'Raipur': Raipur[1]})

# %%
pitchdf
# Out:
#             Ground  Cskplayed  Cskwon    Win%   Lose%        Lat       Long
# 0          Chennai         56      40   71.43   28.57  13.087840  80.278470
# 1           Mumbai         25      15   60.00   40.00  19.072830  72.882610
# 2            Dubai         14       9   64.29   35.71  25.276987  55.296249
# 3          Kolkata         11       5   45.45   54.55  22.562630  88.363040
# 4            Delhi         10       7   70.00   30.00  28.651950  77.231490
# 5        Bengaluru          9       5   55.56   44.44  12.971940  77.593690
# 6             Pune          8       6   75.00   25.00  18.519570  73.855350
# 7        Abu Dhabi          8       4   50.00   50.00  24.466667  54.366669
# 8          Sharjah          6       3   50.00   50.00  25.346255  55.420932
# 9           Mohali          6       3   50.00   50.00  30.679950  76.722110
# 10          Jaipur          6       3   50.00   50.00  26.919620  75.787810
# ...

# %%
'''def win(row):

    iframe = folium.IFrame(row['Win%'],  # places your content in the iframe
                       width=200,
                       height=200  # adjust size to your needs
                       )

    marker1 = folium.map.Marker(
        [row['Lat'],row['Long']],
        # Create an icon as a text label
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            #html='<div style="font-size: 30; color:#00;"></div>',
            )
        ).add_child(folium.Popup(iframe))
    site_map.add_child(marker1)
'''

# %%
def win1(row):
    circle1 = folium.Circle([row['Lat'],row['Long']], radius=1000, color='#000000', fill=True).add_child(folium.Popup(row['Win%']))
    marker1 = folium.map.Marker(
        [row['Lat'],row['Long']],
        # Create an icon as a text label
        icon=DivIcon(
            icon_size=(20,20),
            icon_anchor=(0,0),
            #html='<div style="font-size: 30; color:#00;"></div>',
            )
        ).add_child(folium.Popup(row['Win%']))
    site_map.add_child(marker1)
    site_map.add_child(circle1)

# %%
pitchdf.apply(win1, axis = 1)
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    None
# 25    None
# 26    None
# dtype: object

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
