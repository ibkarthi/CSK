# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ipl_t20(html).csv')

# %%
iplt20 = df.copy()

# %%
iplt20.head()
# Out:
#   Match        Date                                              Teams  \
# 0     1  18/04/2008  Royal Challengers Bangalore v Kolkata Knight R...
# 1     2  19/04/2008                 Punjab Kings v Chennai Super Kings
# 2     3  19/04/2008                  Delhi Capitals v Rajasthan Royals
# 3     4  20/04/2008            Kolkata Knight Riders v Deccan Chargers
# 4     5  20/04/2008       Mumbai Indians v Royal Challengers Bangalore
#
#                  Ground                                        Result
# 0  Bengaluru, Bangalore         Kolkata Knight Riders won by 140 Runs
# 1    Mohali, Chandigarh            Chennai Super Kings won by 33 Runs
# 2                 Delhi               Delhi Capitals won by 9 Wickets
# 3               Kolkata        Kolkata Knight Riders won by 5 Wickets
# 4                Mumbai  Royal Challengers Bangalore won by 5 Wickets

# %%
iplt20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884 entries, 0 to 883
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Match   884 non-null    object
#  1   Date    884 non-null    object
#  2   Teams   884 non-null    object
#  3   Ground  884 non-null    object
#  4   Result  884 non-null    object
# dtypes: object(5)
# memory usage: 34.7+ KB

# %%
iplt20['Date'] = pd.to_datetime(iplt20['Date'], dayfirst = True)

# %%
iplt20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 884 entries, 0 to 883
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Match   884 non-null    object
#  1   Date    884 non-null    datetime64[ns]
#  2   Teams   884 non-null    object
#  3   Ground  884 non-null    object
#  4   Result  884 non-null    object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 34.7+ KB

# %%
iplt20['Date'][0].year
# Out:
# 2008

# %%
iplt20['Date'][0].month
# Out:
# 4

# %%
iplt20['Date'].dt.isocalendar()
# Out:
#      year  week  day
# 0    2008    16    5
# 1    2008    16    6
# 2    2008    16    6
# 3    2008    16    7
# 4    2008    16    7
# ..    ...   ...  ...
# 879  2021    40    5
# 880  2021    40    7
# 881  2021    41    1
# 882  2021    41    3
# 883  2021    41    5
#
# [884 rows x 3 columns]

# %%
iplt20['Team1'] = iplt20['Teams'].str.split(' v ').str[0]

# %%
iplt20['Team2'] = iplt20['Teams'].str.split(' v ').str[1]

# %%
iplt20['Team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Mumbai Indians', 'Rajasthan Royals',
#        'Deccan Chargers', 'Chennai Super Kings', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Gujarat Lions',
#        'Rising Pune Supergiant'], dtype=object)

# %%
iplt20['Winner'] = iplt20['Result'].str.split(' won by ').str[0]

# %%
iplt20.head()
# Out:
#   Match       Date                                              Teams  \
# 0     1 2008-04-18  Royal Challengers Bangalore v Kolkata Knight R...
# 1     2 2008-04-19                 Punjab Kings v Chennai Super Kings
# 2     3 2008-04-19                  Delhi Capitals v Rajasthan Royals
# 3     4 2008-04-20            Kolkata Knight Riders v Deccan Chargers
# 4     5 2008-04-20       Mumbai Indians v Royal Challengers Bangalore
#
#                  Ground                                        Result  \
# 0  Bengaluru, Bangalore         Kolkata Knight Riders won by 140 Runs
# 1    Mohali, Chandigarh            Chennai Super Kings won by 33 Runs
# 2                 Delhi               Delhi Capitals won by 9 Wickets
# 3               Kolkata        Kolkata Knight Riders won by 5 Wickets
# 4                Mumbai  Royal Challengers Bangalore won by 5 Wickets
#
#                          Team1                        Team2  \
# ...

# %%
iplt20['Team2'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Royal Challengers Bangalore', 'Punjab Kings',
#        'Delhi Capitals', 'Mumbai Indians', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Gujarat Lions'], dtype=object)

# %%
iplt20['Team1'] = iplt20['Team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
iplt20['Team2'] = iplt20['Team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
iplt20['Team1'] = iplt20['Team1'].str.replace('Rising Pune Supergiant','Pune Warriors')
iplt20['Team2'] = iplt20['Team2'].str.replace('Rising Pune Supergiant','Pune Warriors')

# %%
iplt20['Winner'] = iplt20['Winner'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
iplt20['Winner'] = iplt20['Winner'].str.replace('Rising Pune Supergiant','Pune Warriors')

# %%
iplt20.head()
# Out:
#   Match       Date                                              Teams  \
# 0     1 2008-04-18  Royal Challengers Bangalore v Kolkata Knight R...
# 1     2 2008-04-19                 Punjab Kings v Chennai Super Kings
# 2     3 2008-04-19                  Delhi Capitals v Rajasthan Royals
# 3     4 2008-04-20            Kolkata Knight Riders v Deccan Chargers
# 4     5 2008-04-20       Mumbai Indians v Royal Challengers Bangalore
#
#                  Ground                                        Result  \
# 0  Bengaluru, Bangalore         Kolkata Knight Riders won by 140 Runs
# 1    Mohali, Chandigarh            Chennai Super Kings won by 33 Runs
# 2                 Delhi               Delhi Capitals won by 9 Wickets
# 3               Kolkata        Kolkata Knight Riders won by 5 Wickets
# 4                Mumbai  Royal Challengers Bangalore won by 5 Wickets
#
#                          Team1                        Team2  \
# ...

# %%
iplt20['Winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bangalore', 'Rajasthan Royals', 'Punjab Kings',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Match abandoned',
#        'Match tied (Rajasthan Royals won eliminator)',
#        'Match tied (Punjab Kings won eliminator)', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'No result',
#        'Match tied (Sunrisers Hyderabad won eliminator)',
#        'Match tied (Royal Challengers Bangalore won eliminator)',
#        'Gujarat Lions', 'Match tied (Mumbai Indians won eliminator)',
#        'Match tied (Delhi Capitals won eliminator)',
#        'Match tied (Kolkata Knight Riders won eliminator)'], dtype=object)

# %%
def cleancell(df):
    if 'Match tied' in df['Winner']:
        if df['Winner'] in df['Team1']:
            return df['Team1']
        else:
            return df['Team2']
    else:
        return df['Winner']

# %%
iplt20['Winner'] = iplt20.apply(cleancell, axis = 1)

# %%
iplt20['Winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bangalore', 'Rajasthan Royals', 'Punjab Kings',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Match abandoned',
#        'Pune Warriors', 'Kochi Tuskers Kerala', 'No result',
#        'Gujarat Lions'], dtype=object)

# %%
iplt20.shape
# Out:
# (884, 8)

# %%
iplt20['Winner'] = iplt20['Winner'].replace('Match abandoned', np.nan)

# %%
iplt20['Winner'] = iplt20['Winner'].replace('No result', np.nan)

# %%
iplt20 = iplt20.dropna(axis = 0)

# %%
iplt20.shape
# Out:
# (872, 8)

# %%
iplt20['Winner'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Delhi Capitals',
#        'Royal Challengers Bangalore', 'Rajasthan Royals', 'Punjab Kings',
#        'Sunrisers Hyderabad', 'Mumbai Indians', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'Gujarat Lions'], dtype=object)

# %%
iplt20['Ground'].unique()
# Out:
# array(['Bengaluru, Bangalore', 'Mohali, Chandigarh', 'Delhi', 'Kolkata',
#        'Mumbai', 'Jaipur', 'Hyderabad', 'Chennai', 'Cape Town',
#        'Port Elizabeth', 'Durban', 'Centurion', 'East London',
#        'Johannesburg', 'Kimberley', 'Bloemfontein', 'Cuttack',
#        'Ahmedabad', 'Nagpur', 'Dharamsala', 'Kochi', 'Indore',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', 'Dubai', 'Khandheri, Rajkot', 'Kanpur'], dtype=object)

# %%
iplt20['Ground'] = iplt20['Ground'].replace('Bengaluru, Bangalore', 'Bengaluru')
iplt20['Ground'] = iplt20['Ground'].replace('Mohali, Chandigarh', 'Mohali')

# %%
iplt20['Ground'].unique()
# Out:
# array(['Bengaluru', 'Mohali', 'Delhi', 'Kolkata', 'Mumbai', 'Jaipur',
#        'Hyderabad', 'Chennai', 'Cape Town', 'Port Elizabeth', 'Durban',
#        'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Cuttack', 'Ahmedabad', 'Nagpur', 'Dharamsala',
#        'Kochi', 'Indore', 'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi',
#        'Abu Dhabi', 'Sharjah', 'Dubai', 'Khandheri, Rajkot', 'Kanpur'],
#       dtype=object)

# %%
iplt20['Result'].unique()
# Out:
# array(['Kolkata Knight Riders won by 140 Runs',
#        'Chennai Super Kings won by 33 Runs',
#        'Delhi Capitals won by 9 Wickets',
#        'Kolkata Knight Riders won by 5 Wickets',
#        'Royal Challengers Bangalore won by 5 Wickets',
#        'Rajasthan Royals won by 6 Wickets',
#        'Chennai Super Kings won by 6 Runs',
#        'Rajasthan Royals won by 3 Wickets', 'Punjab Kings won by 66 Runs',
#        'Chennai Super Kings won by 9 Wickets',
#        'Rajasthan Royals won by 7 Wickets',
#        'Punjab Kings won by 4 Wickets',
#        'Deccan Chargers won by 10 Wickets',
#        'Chennai Super Kings won by 13 Runs',
#        'Mumbai Indians won by 7 Wickets', 'Delhi Capitals won by 10 Runs',
#        'Rajasthan Royals won by 45 Runs', 'Punjab Kings won by 7 Wickets',
#        'Delhi Capitals won by 8 Wickets',
#        'Royal Challengers Bangalore won by 3 Runs',
#        'Punjab Kings won by 9 Runs', 'Mumbai Indians won by 29 Runs',
# ...

# %%
def cleancell1(df):
    if 'Match tied' in df['Result']:
        if df['Result'] in df['Team1']:
            return (df['Team1'] + ' won by tie')
        else:
            return (df['Team2'] + ' won by tie')
    else:
        return df['Result']

# %%
iplt20['Result'] = iplt20.apply(cleancell1, axis = 1)

# %%
iplt20['Result'].unique()
# Out:
# array(['Kolkata Knight Riders won by 140 Runs',
#        'Chennai Super Kings won by 33 Runs',
#        'Delhi Capitals won by 9 Wickets',
#        'Kolkata Knight Riders won by 5 Wickets',
#        'Royal Challengers Bangalore won by 5 Wickets',
#        'Rajasthan Royals won by 6 Wickets',
#        'Chennai Super Kings won by 6 Runs',
#        'Rajasthan Royals won by 3 Wickets', 'Punjab Kings won by 66 Runs',
#        'Chennai Super Kings won by 9 Wickets',
#        'Rajasthan Royals won by 7 Wickets',
#        'Punjab Kings won by 4 Wickets',
#        'Deccan Chargers won by 10 Wickets',
#        'Chennai Super Kings won by 13 Runs',
#        'Mumbai Indians won by 7 Wickets', 'Delhi Capitals won by 10 Runs',
#        'Rajasthan Royals won by 45 Runs', 'Punjab Kings won by 7 Wickets',
#        'Delhi Capitals won by 8 Wickets',
#        'Royal Challengers Bangalore won by 3 Runs',
#        'Punjab Kings won by 9 Runs', 'Mumbai Indians won by 29 Runs',
# ...

# %%
iplt20['Win by'] = iplt20['Result'].str.split(' won by ').str[1]

# %%
iplt20['Win by'].unique()
# Out:
# array(['140 Runs', '33 Runs', '9 Wickets', '5 Wickets', '6 Wickets',
#        '6 Runs', '3 Wickets', '66 Runs', '7 Wickets', '4 Wickets',
#        '10 Wickets', '13 Runs', '10 Runs', '45 Runs', '8 Wickets',
#        '3 Runs', '9 Runs', '29 Runs', '5 Runs', '18 Runs', '23 Runs',
#        '12 Runs', '65 Runs', '6 Runs [D/L]', '3 Runs [D/L]', '25 Runs',
#        '1 Run', '14 Runs', '41 Runs', '105 Runs', '19 Runs', '75 Runs',
#        '10 Wickets [D/L]', '92 Runs', '11 Runs [D/L]', '24 Runs', 'tie',
#        '27 Runs', '38 Runs', '8 Runs', '78 Runs', '12 Runs [D/L]',
#        '16 Runs', '53 Runs', '2 Wickets', '2 Runs', '11 Runs', '4 Runs',
#        '31 Runs', '55 Runs', '98 Runs', '34 Runs', '36 Runs', '17 Runs',
#        '39 Runs', '40 Runs', '67 Runs', '63 Runs', '37 Runs', '57 Runs',
#        '35 Runs', '22 Runs', '21 Runs', '48 Runs', '26 Runs', '20 Runs',
#        '85 Runs', '10 Runs [D/L]', '32 Runs', '76 Runs',
# ...

# %%
iplt20[(iplt20['Win by'] == 'Super Over') | (iplt20['Win by'] == 'Boundary Count')]
# Out:
#     Match       Date                                     Teams     Ground  \
# 422    19 2014-04-29  Kolkata Knight Riders v Rajasthan Royals  Abu Dhabi
# 481    18 2015-04-21           Rajasthan Royals v Punjab Kings  Ahmedabad
#
#                                      Result                  Team1  \
# 422  Rajasthan Royals won by Boundary Count  Kolkata Knight Riders
# 481          Punjab Kings won by Super Over       Rajasthan Royals
#
#                 Team2            Winner          Win by
# 422  Rajasthan Royals  Rajasthan Royals  Boundary Count
# 481      Punjab Kings      Punjab Kings      Super Over

# %%
# Super Over - Punjab Kings(Chasing Team)
# Boundary Count - Rajasthan Royals(First batting Team)
def chase(df):
    if ('Runs' in df['Win by']) or ('Boundary Count' in df['Win by']):
        return 'Lost'
    elif 'tie' in df['Win by']:
        return 'Tie'
    else:
        return 'Won'

# %%
iplt20['Chasing Team'] = iplt20.apply(chase, axis = 1)

# %%
iplt20['Chasing Team'].unique()
# Out:
# array(['Lost', 'Won', 'Tie'], dtype=object)

# %%
iplt20.sample(10)
# Out:
#     Match       Date                                              Teams  \
# 515    52 2015-05-15  Sunrisers Hyderabad v Royal Challengers Bangalore
# 538    15 2016-04-21                Gujarat Lions v Sunrisers Hyderabad
# 291    40 2012-04-29                   Mumbai Indians v Deccan Chargers
# 688    45 2018-05-12       Delhi Capitals v Royal Challengers Bangalore
# 771     8 2020-09-26        Kolkata Knight Riders v Sunrisers Hyderabad
# 9      10 2008-04-25                      Punjab Kings v Mumbai Indians
# 802    39 2020-10-21  Kolkata Knight Riders v Royal Challengers Bang...
# 132    15 2010-03-21                   Deccan Chargers v Delhi Capitals
# 681    38 2018-05-06                    Punjab Kings v Rajasthan Royals
# 671    28 2018-04-29             Rajasthan Royals v Sunrisers Hyderabad
#
#         Ground                                             Result  \
# 515  Hyderabad  Royal Challengers Bangalore won by 6 Wickets [...
# ...

# %%
iplt20['Ground'] = iplt20['Ground'].replace('Khandheri, Rajkot', 'Khandheri')

# %%
iplt20.to_csv('ipl_t20(clean).csv', index = False)
